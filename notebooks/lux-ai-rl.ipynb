# %%
# Preparing environment

# !pip install --upgrade luxai_s2
# !pip install pettingzoo==1.12.0 gym==0.21.0 stable-baselines3
# !pip install --upgrade --quiet cloudpickle pickle5
# !pip install --upgrade "importlib_metadata<5.0"

# %%writefile /opt/conda/lib/python3.7/site-packages/luxai_s2/version.py
__version__ = ""

import importlib
import importlib_metadata
# kaggle has 6.0.0 installed but we need version <5.0
importlib.reload(importlib_metadata)

# %%
from pathlib import Path

if not Path('.git').exists():
    # !git clone https://github.com/aI-lab-glider/lux-ai-challenge .
else: 
    # !git pull
# Out:
# Already up to date.

# %%
# !python rl_agents/train.py -l logs/exp_1 -s 42 -n 2

# %%
# move weights
# !ls logs/exp_1/models
# !mv logs/exp_1/models/best_model.zip rl_agents/best_model.zip

# %%
# !luxai-s2 rl_main.py heuristics_main.py -v 2 -s 101 -o replay.json
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.7.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 42: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# 43: Invalid movement action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to move to (7, 37) requiring 78 power
# 44: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# 45: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# 46: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# 47: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# 48: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# 49: Invalid Dig Action for unit [0] unit_6 UnitType.HEAVY at (7, 38) - Tried to dig requiring 60 power
# ...
